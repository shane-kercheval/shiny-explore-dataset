# %%
# !pip install oolearning --upgrade

# %%
from oolearning import *
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
width = 10
plt.rcParams['figure.figsize'] = [width, width/1.333]

# %%
csv_file = '../shiny-explore-dataset/example_datasets/credit.csv'
target_variable = 'default'

explore = ExploreClassificationDataset.from_csv(csv_file_path=csv_file,
                                                target_variable=target_variable)

# %%
explore.dataset
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0    < 0 DM           6                     critical
# 1    1 - 200 DM       48                    good
# 2    unknown          12                    critical
# 3    < 0 DM           42                    good
# 4    < 0 DM           24                    poor
# 5    unknown          36                    good
# 6    unknown          24                    good
# 7    1 - 200 DM       36                    good
# 8    unknown          12                    good
# 9    1 - 200 DM       30                    critical
# 10   1 - 200 DM       12                    good
# 11   < 0 DM           48                    good
# 12   1 - 200 DM       12                    good
# 13   < 0 DM           24                    critical
# 14   < 0 DM           15                    good
# 15   < 0 DM           24                    good
# 16   unknown          24                    critical
# ...

# %%
explore.plot_correlation_heatmap()

# %%
explore.numeric_summary()
# Out:
#                       count  nulls  perc_nulls  num_zeros  perc_zeros  \
# months_loan_duration  1000   0      0.0         0          0.0
# amount                1000   0      0.0         0          0.0
# percent_of_income     1000   0      0.0         0          0.0
# years_at_residence    1000   0      0.0         0          0.0
# age                   1000   0      0.0         0          0.0
# existing_loans_count  1000   0      0.0         0          0.0
# dependents            1000   0      0.0         0          0.0
#
#                           mean    st_dev  coef of var  skewness  kurtosis  \
# months_loan_duration  20.903    12.059    0.577        1.094     0.920
# amount                3271.258  2822.737  0.863        1.950     4.293
# percent_of_income     2.973     1.119     0.376       -0.531    -1.210
# years_at_residence    2.845     1.104     0.388       -0.273    -1.381
# age                   35.546    11.375    0.320        1.021     0.596
# ...

# %%
explore.categoric_summary()
# Out:
#                      count  nulls  perc_nulls                   top  unique  \
# checking_balance     1000   0      0.0         unknown               4
# credit_history       1000   0      0.0         good                  5
# purpose              1000   0      0.0         furniture/appliances  6
# savings_balance      1000   0      0.0         < 100 DM              5
# employment_duration  1000   0      0.0         1 - 4 years           5
# other_credit         1000   0      0.0         none                  3
# housing              1000   0      0.0         own                   3
# job                  1000   0      0.0         skilled               4
# phone                1000   0      0.0         no                    2
# default              1000   0      0.0         no                    2
#
#                      perc_unique
# checking_balance     0.004
# credit_history       0.005
# purpose              0.006
# savings_balance      0.005
# employment_duration  0.005
# ...

# %%
explore.unique_values('checking_balance')
# Out:
#             freq   perc
# unknown     394   0.394
# < 0 DM      274   0.274
# 1 - 200 DM  269   0.269
# > 200 DM    63    0.063

# %%
explore.plot_unique_values('checking_balance')

# %%
explore.plot_against_target('checking_balance')

# %%
explore.plot_boxplot('months_loan_duration')

# %%
explore.plot_against_target('months_loan_duration')

# %%
explore.plot_histogram('months_loan_duration')

# %%
explore.plot_histogram_against_target('months_loan_duration')

# %%
csv_file = '../shiny-explore-dataset/example_datasets/housing.csv'
target_variable = 'median_house_value'

explore = ExploreRegressionDataset.from_csv(csv_file_path=csv_file,
                                                target_variable=target_variable)

# %%
explore.categoric_summary()
# Out:
#                  count  nulls  perc_nulls        top  unique  perc_unique
# ocean_proximity  20640  0      0.0         <1H OCEAN  5       0.0

# %%
explore.numeric_summary()
# Out:
#                     count  nulls  perc_nulls  num_zeros  perc_zeros  \
# longitude           20640  0      0.00        0          0.0
# latitude            20640  0      0.00        0          0.0
# housing_median_age  20640  0      0.00        0          0.0
# total_rooms         20640  0      0.00        0          0.0
# total_bedrooms      20433  207    0.01        0          0.0
# population          20640  0      0.00        0          0.0
# households          20640  0      0.00        0          0.0
# median_income       20640  0      0.00        0          0.0
# median_house_value  20640  0      0.00        0          0.0
#
#                           mean      st_dev  coef of var  skewness  kurtosis  \
# longitude          -119.570     2.004      -0.017       -0.298    -1.330
# latitude            35.632      2.136       0.060        0.466    -1.118
# housing_median_age  28.639      12.586      0.439        0.060    -0.801
# ...

# %%
explore.plot_against_target('ocean_proximity')

# %%
explore.plot_against_target('median_income')

# %%
transformations = [DummyEncodeTransformer(CategoricalEncoding.DUMMY)]
